# %%
import os
import sys
import sqlite3

import numpy as np
import pandas as pd
import geopandas as gp
import skill_metrics as sm

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import scipy. stats as scs
import xgboost as xgb
from skopt import BayesSearchCV
from skopt.space import Real, Integer

from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel, RFE
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, precision_score, recall_score, f1_score, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-08-14 19:39:13.529264: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-14 19:39:13.753660: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-14 19:39:13.937595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755187754.097114    2223 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755187754.139530    2223 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755187754.495251    2223 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755187754.495277    2223 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755187754.495278    2223 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755187754.495280    2223 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-14 19:39:14.531104: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sys.path.append('/home/pooya/w/DroughtMonitoringIran/')

DATABASE_PATH = "./database/database.db"

# %% [markdown]
# ### Monthly Data

# %%
conn = sqlite3.connect(DATABASE_PATH)

data = pd.read_sql(sql='SELECT * FROM data', con=conn)

conn.close()

# %% [markdown]
# ### Select Columns

# %%
data.columns.to_list()
# Out:
# ['Station_ID',
#  'Station_Name',
#  'Province',
#  'Station_Latitude',
#  'Station_Longitude',
#  'Station_Elevation',
#  'Date',
#  'Temperature_Maximum',
#  'Temperature_Minimum',
#  'Temperature',
#  'Precipitation',
#  'PET_Hargreaves',
#  'SPI_1',
#  'SPEI_1',
#  'SPI_3',
#  'SPEI_3',
#  'SPI_6',
#  'SPEI_6',
#  'SPI_9',
#  'SPEI_9',
#  'SPI_12',
#  'SPEI_12',
#  'SPI_15',
#  'SPEI_15',
#  'SPI_18',
#  'SPEI_18',
#  'SPI_21',
#  'SPEI_21',
#  'SPI_24',
#  'SPEI_24',
#  'ERA5_Precipitation',
#  'GPM_Precipitation',
#  'TRMM_Precipitation',
#  'TERRACLIMATE_Precipitation',
#  'PERSIANNCDR_Precipitation',
#  'PET_MOD16A2GF',
#  'NDVI_MOD13A3',
#  'LSTDay_MOD21C3',
#  'LSTNight_MYD21C3',
#  'EVI_MYD13A3',
#  'LSTNight_MOD21C3',
#  'NDVI_MYD13A3',
#  'LSTDay_MYD21C3',
#  'EVI_MOD13A3',
#  'NDVI',
#  'EVI',
#  'LSTDay',
#  'LSTNight',
#  'LST',
#  'PCI_ERA5',
#  'PCI_GPM',
#  'PCI_TRMM',
#  'PCI_TerraClimate',
#  'PCI_PERSIANNCDR',
#  'VCI',
#  'TCI',
#  'VHI',
#  'CI_GPM',
#  'CI_ERA5',
#  'CI_TRMM',
#  'CI_TerraClimate',
#  'CI_PERSIANNCDR',
#  'ERA5_SPI_1',
#  'ERA5_SPEI_1',
#  'GPM_SPI_1',
#  'GPM_SPEI_1',
#  'TRMM_SPI_1',
#  'TRMM_SPEI_1',
#  'TERRACLIMATE_SPI_1',
#  'TERRACLIMATE_SPEI_1',
#  'PERSIANNCDR_SPI_1',
#  'PERSIANNCDR_SPEI_1',
#  'ERA5_SPI_3',
#  'ERA5_SPEI_3',
#  'GPM_SPI_3',
#  'GPM_SPEI_3',
#  'TRMM_SPI_3',
#  'TRMM_SPEI_3',
#  'TERRACLIMATE_SPI_3',
#  'TERRACLIMATE_SPEI_3',
#  'PERSIANNCDR_SPI_3',
#  'PERSIANNCDR_SPEI_3',
#  'ERA5_SPI_6',
#  'ERA5_SPEI_6',
#  'GPM_SPI_6',
#  'GPM_SPEI_6',
#  'TRMM_SPI_6',
#  'TRMM_SPEI_6',
#  'TERRACLIMATE_SPI_6',
#  'TERRACLIMATE_SPEI_6',
#  'PERSIANNCDR_SPI_6',
#  'PERSIANNCDR_SPEI_6',
#  'ERA5_SPI_9',
#  'ERA5_SPEI_9',
#  'GPM_SPI_9',
#  'GPM_SPEI_9',
#  'TRMM_SPI_9',
#  'TRMM_SPEI_9',
#  'TERRACLIMATE_SPI_9',
#  'TERRACLIMATE_SPEI_9',
#  'PERSIANNCDR_SPI_9',
#  'PERSIANNCDR_SPEI_9',
#  'ERA5_SPI_12',
#  'ERA5_SPEI_12',
#  'GPM_SPI_12',
#  'GPM_SPEI_12',
#  'TRMM_SPI_12',
#  'TRMM_SPEI_12',
#  'TERRACLIMATE_SPI_12',
#  'TERRACLIMATE_SPEI_12',
#  'PERSIANNCDR_SPI_12',
#  'PERSIANNCDR_SPEI_12',
#  'ERA5_SPI_15',
#  'ERA5_SPEI_15',
#  'GPM_SPI_15',
#  'GPM_SPEI_15',
#  'TRMM_SPI_15',
#  'TRMM_SPEI_15',
#  'TERRACLIMATE_SPI_15',
#  'TERRACLIMATE_SPEI_15',
#  'PERSIANNCDR_SPI_15',
#  'PERSIANNCDR_SPEI_15',
#  'ERA5_SPI_18',
#  'ERA5_SPEI_18',
#  'GPM_SPI_18',
#  'GPM_SPEI_18',
#  'TRMM_SPI_18',
#  'TRMM_SPEI_18',
#  'TERRACLIMATE_SPI_18',
#  'TERRACLIMATE_SPEI_18',
#  'PERSIANNCDR_SPI_18',
#  'PERSIANNCDR_SPEI_18',
#  'ERA5_SPI_21',
#  'ERA5_SPEI_21',
#  'GPM_SPI_21',
#  'GPM_SPEI_21',
#  'TRMM_SPI_21',
#  'TRMM_SPEI_21',
#  'TERRACLIMATE_SPI_21',
#  'TERRACLIMATE_SPEI_21',
#  'PERSIANNCDR_SPI_21',
#  'PERSIANNCDR_SPEI_21',
#  'ERA5_SPI_24',
#  'ERA5_SPEI_24',
#  'GPM_SPI_24',
#  'GPM_SPEI_24',
#  'TRMM_SPI_24',
#  'TRMM_SPEI_24',
#  'TERRACLIMATE_SPI_24',
#  'TERRACLIMATE_SPEI_24',
#  'PERSIANNCDR_SPI_24',
#  'PERSIANNCDR_SPEI_24']

# %%
di = 'SPI'
di_scale = 3

selected_columns = [
    'Station_ID',
    'Station_Latitude', 'Station_Longitude', 'Station_Elevation',
    'Date', # 'Year', 'Month',
    f'{di}_{di_scale}',
    'GPM_Precipitation',
    'PET_MOD16A2GF',
    'NDVI', 'EVI',
    'LSTDay', 'LSTNight', 'LST',
    'PCI_GPM', 'VCI', 'TCI', 'VHI', 'CI_GPM',
    f'GPM_{di}_{di_scale}'
 ]

# %% [markdown]
# ### Define Dataset

# %%
df = data.filter(items=selected_columns)
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Station_ID'] = df['Station_ID'].astype('category')
df.drop(columns=['Date'], inplace=True)
df.dropna(inplace=True)
df.sort_values(by=['Station_ID', 'Year', 'Month'], inplace=True)
df.reset_index(drop=True, inplace=True)
df[f'{di}_{di_scale}_Class'] = pd.cut(df[f'{di}_{di_scale}'], bins=[-10, -2, -1.5, -1, 1, 1.5, 2, 10], labels=['ED', 'SD', 'MD', 'NN', 'MW', 'VW', 'EW'])
df[f'GPM_{di}_{di_scale}_Class'] = pd.cut(df[f'GPM_{di}_{di_scale}'], bins=[-10, -2, -1.5, -1, 1, 1.5, 2, 10], labels=['ED', 'SD', 'MD', 'NN', 'MW', 'VW', 'EW'])
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4944 entries, 0 to 4943
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Station_ID         4944 non-null   category
#  1   Station_Latitude   4944 non-null   float64
#  2   Station_Longitude  4944 non-null   float64
#  3   Station_Elevation  4944 non-null   float64
#  4   SPI_3              4944 non-null   float64
#  5   GPM_Precipitation  4944 non-null   float64
#  6   PET_MOD16A2GF      4944 non-null   float64
#  7   NDVI               4944 non-null   float64
#  8   EVI                4944 non-null   float64
#  9   LSTDay             4944 non-null   float64
#  10  LSTNight           4944 non-null   float64
#  11  LST                4944 non-null   float64
#  12  PCI_GPM            4944 non-null   float64
#  13  VCI                4944 non-null   float64
#  14  TCI                4944 non-null   float64
#  15  VHI                4944 non-null   float64
#  16  CI_GPM             4944 non-null   float64
#  17  GPM_SPI_3          4944 non-null   float64
#  18  Year               4944 non-null   int32
#  19  Month              4944 non-null   int32
#  20  SPI_3_Class        4944 non-null   category
#  21  GPM_SPI_3_Class    4944 non-null   category
# dtypes: category(3), float64(17), int32(2)
# memory usage: 711.3 KB
# None
#      Station_ID  Station_Latitude  Station_Longitude  Station_Elevation  \
# 0         40709            38.365             48.855              -21.1
# 1         40709            38.365             48.855              -21.1
# 2         40709            38.365             48.855              -21.1
# 3         40709            38.365             48.855              -21.1
# 4         40709            38.365             48.855              -21.1
# ...         ...               ...                ...                ...
# 4939      99361            36.071             52.843             1805.0
# 4940      99361            36.071             52.843             1805.0
# 4941      99361            36.071             52.843             1805.0
# 4942      99361            36.071             52.843             1805.0
# 4943      99361            36.071             52.843             1805.0
#
#       SPI_3  GPM_Precipitation  PET_MOD16A2GF   NDVI    EVI  LSTDay  ...  \
# 0     0.022            101.520         44.000  0.554  0.286   17.30  ...
# 1     0.104             77.376         35.025  0.462  0.236   10.15  ...
# 2    -1.009             26.040         60.400  0.418  0.195    9.84  ...
# 3     0.205            129.024         58.100  0.459  0.218   10.28  ...
# 4     0.521            100.440         76.400  0.485  0.234   11.28  ...
# ...     ...                ...            ...    ...    ...     ...  ...
# 4939  0.428             20.088        239.275  0.420  0.219   34.26  ...
# 4940 -0.357             35.280        176.650  0.380  0.175   26.76  ...
# 4941  0.031             64.728        123.012  0.394  0.185   22.45  ...
# 4942  0.271             46.080         98.800  0.395  0.187   17.29  ...
# 4943 -0.079             23.064         57.588  0.453  0.183   11.68  ...
#
#       PCI_GPM    VCI    TCI    VHI  CI_GPM  GPM_SPI_3  Year  Month  \
# 0       0.411  0.651  0.377  0.514   0.480      0.531  2006     11
# 1       0.522  0.460  0.916  0.688   0.633      0.204  2006     12
# 2       0.000  0.486  0.213  0.350   0.233     -0.689  2007      1
# 3       0.797  0.897  0.390  0.643   0.694     -0.438  2007      2
# 4       0.500  0.954  1.000  0.977   0.818      0.113  2007      3
# ...       ...    ...    ...    ...     ...        ...   ...    ...
# 4939    0.222  0.537  0.274  0.406   0.345      0.116  2023      8
# 4940    0.455  0.375  0.948  0.662   0.593     -0.212  2023      9
# 4941    0.522  0.445  0.699  0.572   0.555      0.387  2023     10
# 4942    0.331  0.706  0.000  0.353   0.346     -0.089  2023     11
# 4943    0.080  1.000  0.056  0.528   0.379     -0.633  2023     12
#
#       SPI_3_Class  GPM_SPI_3_Class
# 0              NN               NN
# 1              NN               NN
# 2              MD               NN
# 3              NN               NN
# 4              NN               NN
# ...           ...              ...
# 4939           NN               NN
# 4940           NN               NN
# 4941           NN               NN
# 4942           NN               NN
# 4943           NN               NN
#
# [4944 rows x 22 columns]

# %% [markdown]
# ### X, y

# %%
X = df.drop(
    columns=[
        'Station_ID',
        f'{di}_{di_scale}',
        f'{di}_{di_scale}_Class',
        f'GPM_{di}_{di_scale}',
        f'GPM_{di}_{di_scale}_Class'
    ]
)

y = df[f'{di}_{di_scale}']

# %% [markdown]
# ###  Scale the Features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### Split the data into training and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=1
)

# %% [markdown]
# ### Step 1: Apply Scaling to the features

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_scaled = scaler.transform(X)

# %% [markdown]
# ### Step 2: Feature selection using Random Forest

# %%
rf = RandomForestRegressor(random_state=1)

# rf.fit(X_train_scaled, y_train)
rf.fit(X_scaled, y)

importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

# print("Feature Importance:")
# for f in range(X_train.shape[1]):
#     print(f"{X_train.columns[indices[f]]}: {importances[indices[f]]}")
print("Feature Importance:")
for f in range(X.shape[1]):
    print(f"{X.columns[indices[f]]}: {importances[indices[f]]}")

sfm = SelectFromModel(
    estimator=rf,
    threshold="mean",
    max_features=3
)

# sfm.fit(X_train_scaled, y_train)
sfm.fit(X_scaled, y)

X_train_selected = sfm.transform(X_train_scaled)
X_test_selected = sfm.transform(X_test_scaled)
X_selected = sfm.transform(X_scaled)
# Out:
# Feature Importance:
# Year: 0.22006878369357533
# CI_GPM: 0.1619400357818095
# PET_MOD16A2GF: 0.06892030304788889
# Month: 0.06488602681308728
# GPM_Precipitation: 0.056976428266922396
# PCI_GPM: 0.05349504235345927
# TCI: 0.0514459390393451
# LSTNight: 0.03706285810981096
# LSTDay: 0.0364781954651036
# VCI: 0.035102962483066956
# NDVI: 0.03410170194392762
# LST: 0.03309146068883459
# EVI: 0.032594400682092246
# VHI: 0.031519847744046585
# Station_Longitude: 0.030793898745182336
# Station_Elevation: 0.027274507131068344
# Station_Latitude: 0.024247608010778892

# %% [markdown]
# ### Step 3: Hyperparameter tuning for Random Forest

# %%
rf_param_grid = {
    'n_estimators': [400],
    'max_depth': [20],
    'min_samples_split': [5],
    'min_samples_leaf': [2]
}

rf_grid_search = GridSearchCV(
    estimator=RandomForestRegressor(random_state=1),
    param_grid=rf_param_grid, 
    cv=5, 
    scoring='neg_mean_squared_error'
)

# rf_grid_search.fit(X_train_selected, y_train)
rf_grid_search.fit(X_selected, y)

print("Best Random Forest Hyperparameters:", rf_grid_search.best_params_)
# Out:
# Best Random Forest Hyperparameters: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 400}

# %% [markdown]
# ### Step 4: Evaluate the models

# %%
# rf_best_model = rf_grid_search.best_estimator_
# rf_preds = rf_best_model.predict(X_test_selected)
# rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))
# rf_r2 = r2_score(y_test, rf_preds)
rf_best_model = rf_grid_search.best_estimator_
rf_preds = rf_best_model.predict(X_selected)
rf_rmse = np.sqrt(mean_squared_error(y, rf_preds))
rf_r2 = r2_score(y, rf_preds)

print(f"Random Forest RMSE: {rf_rmse}")
print(f"Random Forest R²: {rf_r2}")
# Out:
# Random Forest RMSE: 0.42216367130018945
# Random Forest R²: 0.8164647579442315

# %%
y.name = 'Actual'

# %%
aaa = pd.concat([y, pd.Series(rf_preds, name='Predicted')], axis=1)

# %%
plot_data = pd.DataFrame([y, rf_preds])
fig = px.scatter(aaa, x='Actual', y='Predicted')
max_limit = max(aaa['Actual'].max(), aaa['Predicted'].max())
min_limit = max(aaa['Actual'].min(), aaa['Predicted'].min())
fig.update_layout(xaxis=dict(range=[min_limit, max_limit]), yaxis=dict(range=[min_limit, max_limit]))
fig.update_yaxes(scaleanchor="x", scaleratio=1)
fig.update_xaxes(constrain='domain')
fig.show()
# Out:
# <div>                            <div id="0e9b378d-4bbb-4a76-b654-9fa5fd05ba41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e9b378d-4bbb-4a76-b654-9fa5fd05ba41")) {                    Plotly.newPlot(                        "0e9b378d-4bbb-4a76-b654-9fa5fd05ba41",                        [{"hovertemplate":"Actual=%{x}\u003cbr\u003ePredicted=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[0.056,0.15,0.612,0.606,0.865,1.231,0.371,-0.903,-2.211,-1.971,-1.929,-2.085,-2.122,-2.419,-1.774,-1.089,-1.079,-1.186,-1.633,-0.845,-0.022,-0.542,-0.289,-0.503,-0.191,-0.048,0.031,-0.186,-1.001,-0.871,1.027,1.109,0.282,0.125,0.226,0.392,-0.459,-0.151,0.469,0.656,0.435,0.211,0.177,0.252,-0.1,-0.915,-1.16,-1.201,-0.525,-0.871,-1.575,-0.436,0.438,0.051,0.039,0.151,-0.25,0.072,-0.344,-0.006,-0.392,-0.388,-0.86,-1.943,-1.827,-1.782,-0.025,-0.283,-0.769,-0.154,-0.211,-0.101,-0.797,-0.279,0.458,-0.249,-0.168,-0.249,-0.284,0.064,-0.024,0.762,0.59,0.573,0.657,0.642,0.354,-0.977,-1.229,-1.255,-2.01,-1.321,0.609,1.074,1.152,1.469,1.891,1.855,0.896,0.376,0.086,0.601,-0.068,-1.325,0.926,1.136,1.459,1.339,1.394,1.902,0.84,0.323,0.266,0.562,0.271,0.926,1.435,1.163,1.028,0.586,1.049,0.107,-0.789,-0.884,-0.572,-0.511,-1.011,-0.387,-0.183,-0.615,-1.097,-0.917,-0.458,-0.586,-1.393,-1.215,-0.627,-1.023,-0.445,0.137,0.127,1.507,1.252,1.318,1.24,1.654,2.008,1.361,1.441,1.843,1.93,1.399,0.186,-0.031,0.168,0.141,-0.314,0.143,1.279,1.668,1.548,1.1,1.49,0.382,-1.723,-1.321,-0.97,-1.196,-1.484,-1.054,-0.275,-0.483,-1.059,0.216,-0.773,0.548,0.497,0.439,0.37,-0.088,0.411,0.491,0.296,0.201,0.323,-0.019,-0.203,-1.875,-1.369,-1.507,-1.268,-0.968,-0.533,-0.284,-0.443,0.744,0.645,1.019,1.089,1.735,1.821,0.201,0.548,1.591,1.453,2.005,1.683,0.456,1.144,0.299,0.057,-1.9,-1.539,-1.919,-1.071,-0.23,-0.904,0.055,0.275,0.886,-0.741,-1.226,-0.58,0.128,-0.304,0.303,0.444,0.154,0.063,-0.209,0.394,-0.627,-0.847,0.519,0.806,0.001,-0.608,-0.334,-0.758,-1.831,-2.128,-0.492,0.239,-0.238,0.321,0.52,0.499,0.249,-0.592,-1.411,-0.277,-0.075,0.243,-0.186,0.837,2.21,0.857,2.02,1.665,2.115,2.427,2.094,2.199,1.476,1.315,0.64,-1.394,-0.093,0.848,1.093,0.976,0.094,0.859,0.835,0.526,-0.627,-0.757,0.517,-0.523,-1.334,-0.492,-0.337,-0.904,-0.253,0.568,0.509,0.7,0.54,1.092,0.505,-0.485,-0.135,-0.549,-0.751,-1.828,-0.359,-0.132,-0.452,0.085,0.301,1.08,0.469,0.347,0.651,0.515,0.175,-0.97,-0.181,-0.263,-0.093,-0.663,-0.976,0.119,-0.863,-0.806,-0.48,0.897,0.102,0.943,1.548,1.633,1.598,1.526,1.769,1.399,0.639,0.072,-0.044,-0.298,-1.419,-0.466,0.624,0.105,-0.458,0.057,0.121,-1.093,-1.981,-1.746,-1.417,-1.687,-0.397,0.148,-0.294,0.235,0.057,-0.488,-0.834,-0.416,0.643,0.206,0.685,1.362,0.851,0.893,-0.586,0.123,0.563,0.989,0.802,0.483,1.686,1.272,0.577,-0.255,0.877,0.166,-0.89,-0.226,0.308,0.346,-1.904,-0.907,-0.841,-1.324,-1.885,-1.135,-1.457,-1.334,0.531,0.249,0.045,-0.544,-0.245,0.08,-1.562,-1.304,-1.103,-1.433,-1.521,-1.281,-1.928,-2.356,-1.678,-2.297,-0.059,-0.652,-0.083,1.213,0.717,1.319,0.404,0.731,1.082,0.006,-0.12,1.143,1.51,1.865,1.559,0.378,1.206,0.891,-0.152,-1.81,-1.019,-1.058,-0.669,-0.634,-1.039,-0.681,-1.11,-0.465,-1.157,-1.242,-0.48,0.181,0.209,0.499,0.282,0.158,-0.361,0.112,-0.122,-1.153,-1.11,-0.008,0.617,0.049,-0.22,-0.331,-0.252,-1.007,-0.829,-0.131,0.206,-0.05,-0.13,-0.23,-1.193,-1.439,-1.757,-1.77,-1.83,-0.937,-0.206,-0.373,0.259,1.272,0.221,1.151,1.732,1.651,1.914,1.795,1.786,0.998,0.592,0.261,-1.482,-0.303,0.219,0.586,0.672,-0.03,-0.017,-0.133,-0.446,-2.004,-1.491,-0.734,-0.998,-1.537,-0.97,-0.375,-0.468,0.747,0.992,0.974,1.013,0.762,0.757,-0.21,-1.247,-1.371,-1.426,-1.677,-2.025,-0.344,0.361,0.117,0.658,0.995,1.574,1.263,0.804,0.92,0.842,0.6 ...

# %% [markdown]
# # Step-by-Step Code for AdaBoost Regressor

# %% [markdown]
# ### Step 1: Data Preprocessing

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.values)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y.values,
    test_size=0.2,
    random_state=1
)

base_estimator = DecisionTreeRegressor()

adaboost_model = AdaBoostRegressor(
    estimator=base_estimator,
    n_estimators=50, 
    random_state=1
)

adaboost_model.fit(X_train, y_train)

# %% [markdown]
# ### Get Feature Importances

# %%
feature_importances = adaboost_model.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({
    'Feature': ['Station_Latitude', 'Station_Longitude', 'Station_Elevation', 'GPM_Precipitation', 'PET_MOD16A2GF', 'NDVI', 'EVI', 'LSTDay', 'LSTNight', 'LST', 'PCI_GPM', 'VCI', 'TCI', 'VHI', 'CI_GPM', 'Year', 'Month'],
    'Importance': feature_importances
})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the sorted feature importances
print(feature_importance_df)

# %% [markdown]
# ### Select the Top Features

# %%
# Select top N features (e.g., top 5)
top_n = 5
top_features = feature_importance_df['Feature'].head(top_n).values

# Filter the original dataset based on the top features
X_top = df[top_features].values

# Scale the selected features
X_top_scaled = scaler.fit_transform(X_top)

# Split the data into training and test sets
X_train_top, X_test_top, y_train, y_test = train_test_split(X_top_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ###  Retrain AdaBoost with Selected Features

# %%
# Train AdaBoost with the selected top features
adaboost_model_top = AdaBoostRegressor(estimator=base_estimator, n_estimators=50, random_state=42)
adaboost_model_top.fit(X_train_top, y_train)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predict on the test data using the new model
y_pred_top = adaboost_model_top.predict(X_test_top)

# Calculate RMSE and R²
rmse_top = np.sqrt(mean_squared_error(y_test, y_pred_top))
r2_top = r2_score(y_test, y_pred_top)

print(f"RMSE with Top Features: {rmse_top}")
print(f"R² with Top Features: {r2_top}")
