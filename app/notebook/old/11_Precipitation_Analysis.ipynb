# %%
import os
import sys
import sqlite3
import numpy as np
import pandas as pd
import geopandas as gp
import plotly.express as px
import skill_metrics as sm
import skill_metrics as sm
import matplotlib.pyplot as plt
import scipy.stats as scs

# %%
sys.path.append('/home/pooya/w/DroughtMonitoringIran/')

DATABASE_PATH = "./database/database.db"

# %% [markdown]
# ### Monthly Data

# %%
conn = sqlite3.connect(DATABASE_PATH)

data = pd.read_sql(sql='SELECT * FROM data', con=conn)

conn.close()

# %% [markdown]
# ### Columns

# %%
data.columns.to_list()
# Out:
# ['Station_ID',
#  'Station_Name',
#  'Province',
#  'Station_Latitude',
#  'Station_Longitude',
#  'Station_Elevation',
#  'Date',
#  'Temperature_Maximum',
#  'Temperature_Minimum',
#  'Temperature',
#  'Precipitation',
#  'PET_Hargreaves',
#  'SPI_1',
#  'SPEI_1',
#  'SPI_3',
#  'SPEI_3',
#  'SPI_6',
#  'SPEI_6',
#  'SPI_9',
#  'SPEI_9',
#  'SPI_12',
#  'SPEI_12',
#  'SPI_15',
#  'SPEI_15',
#  'SPI_18',
#  'SPEI_18',
#  'SPI_21',
#  'SPEI_21',
#  'SPI_24',
#  'SPEI_24',
#  'ERA5_Precipitation',
#  'GPM_Precipitation',
#  'TRMM_Precipitation',
#  'TERRACLIMATE_Precipitation',
#  'PERSIANNCDR_Precipitation',
#  'PET_MOD16A2GF',
#  'NDVI_MOD13A3',
#  'LSTDay_MOD21C3',
#  'LSTNight_MYD21C3',
#  'EVI_MYD13A3',
#  'LSTNight_MOD21C3',
#  'NDVI_MYD13A3',
#  'LSTDay_MYD21C3',
#  'EVI_MOD13A3',
#  'NDVI',
#  'EVI',
#  'LSTDay',
#  'LSTNight',
#  'LST',
#  'PCI_ERA5',
#  'PCI_GPM',
#  'PCI_TRMM',
#  'PCI_TerraClimate',
#  'PCI_PERSIANNCDR',
#  'VCI',
#  'TCI',
#  'VHI',
#  'CI_GPM',
#  'CI_ERA5',
#  'CI_TRMM',
#  'CI_TerraClimate',
#  'CI_PERSIANNCDR',
#  'ERA5_SPI_1',
#  'ERA5_SPEI_1',
#  'GPM_SPI_1',
#  'GPM_SPEI_1',
#  'TRMM_SPI_1',
#  'TRMM_SPEI_1',
#  'TERRACLIMATE_SPI_1',
#  'TERRACLIMATE_SPEI_1',
#  'PERSIANNCDR_SPI_1',
#  'PERSIANNCDR_SPEI_1',
#  'ERA5_SPI_3',
#  'ERA5_SPEI_3',
#  'GPM_SPI_3',
#  'GPM_SPEI_3',
#  'TRMM_SPI_3',
#  'TRMM_SPEI_3',
#  'TERRACLIMATE_SPI_3',
#  'TERRACLIMATE_SPEI_3',
#  'PERSIANNCDR_SPI_3',
#  'PERSIANNCDR_SPEI_3',
#  'ERA5_SPI_6',
#  'ERA5_SPEI_6',
#  'GPM_SPI_6',
#  'GPM_SPEI_6',
#  'TRMM_SPI_6',
#  'TRMM_SPEI_6',
#  'TERRACLIMATE_SPI_6',
#  'TERRACLIMATE_SPEI_6',
#  'PERSIANNCDR_SPI_6',
#  'PERSIANNCDR_SPEI_6',
#  'ERA5_SPI_9',
#  'ERA5_SPEI_9',
#  'GPM_SPI_9',
#  'GPM_SPEI_9',
#  'TRMM_SPI_9',
#  'TRMM_SPEI_9',
#  'TERRACLIMATE_SPI_9',
#  'TERRACLIMATE_SPEI_9',
#  'PERSIANNCDR_SPI_9',
#  'PERSIANNCDR_SPEI_9',
#  'ERA5_SPI_12',
#  'ERA5_SPEI_12',
#  'GPM_SPI_12',
#  'GPM_SPEI_12',
#  'TRMM_SPI_12',
#  'TRMM_SPEI_12',
#  'TERRACLIMATE_SPI_12',
#  'TERRACLIMATE_SPEI_12',
#  'PERSIANNCDR_SPI_12',
#  'PERSIANNCDR_SPEI_12',
#  'ERA5_SPI_15',
#  'ERA5_SPEI_15',
#  'GPM_SPI_15',
#  'GPM_SPEI_15',
#  'TRMM_SPI_15',
#  'TRMM_SPEI_15',
#  'TERRACLIMATE_SPI_15',
#  'TERRACLIMATE_SPEI_15',
#  'PERSIANNCDR_SPI_15',
#  'PERSIANNCDR_SPEI_15',
#  'ERA5_SPI_18',
#  'ERA5_SPEI_18',
#  'GPM_SPI_18',
#  'GPM_SPEI_18',
#  'TRMM_SPI_18',
#  'TRMM_SPEI_18',
#  'TERRACLIMATE_SPI_18',
#  'TERRACLIMATE_SPEI_18',
#  'PERSIANNCDR_SPI_18',
#  'PERSIANNCDR_SPEI_18',
#  'ERA5_SPI_21',
#  'ERA5_SPEI_21',
#  'GPM_SPI_21',
#  'GPM_SPEI_21',
#  'TRMM_SPI_21',
#  'TRMM_SPEI_21',
#  'TERRACLIMATE_SPI_21',
#  'TERRACLIMATE_SPEI_21',
#  'PERSIANNCDR_SPI_21',
#  'PERSIANNCDR_SPEI_21',
#  'ERA5_SPI_24',
#  'ERA5_SPEI_24',
#  'GPM_SPI_24',
#  'GPM_SPEI_24',
#  'TRMM_SPI_24',
#  'TRMM_SPEI_24',
#  'TERRACLIMATE_SPI_24',
#  'TERRACLIMATE_SPEI_24',
#  'PERSIANNCDR_SPI_24',
#  'PERSIANNCDR_SPEI_24']

# %% [markdown]
# 'Station_ID', 'Station_Name', 'Province', 'Date', 'Precipitation', 'ERA5_Precipitation', 'GPM_Precipitation', 'TRMM_Precipitation', 'TERRACLIMATE_Precipitation', 'PERSIANNCDR_Precipitation',

# %% [markdown]
# ### Unique Station

# %%
data[['Station_ID', 'Station_Name']].drop_duplicates().reset_index(drop=True)
# Out:
#    Station_ID                Station_Name
# 0       40709                      Astara
# 1       40718             Bandar-e-anzali
# 2       40719                       Rasht
# 3       40720                      Manjil
# 4       40732                      Ramsar
# 5       40734                    Nowshahr
# 6       40735                  Siahbisheh
# 7       40736                    Babolsar
# 8       40737                   Gharakhil
# 9       40759                        Sari
# 10      40760                     Kiyasar
# 11      40788  Sari (dasht-e-naz airport)
# 12      40805                    Jirandeh
# 13      99249                      Talesh
# 14      99268                   Kiyashahr
# 15      99276                     Lahijan
# 16      99281                     Masuleh
# 17      99299                     Galugah
# 18      99306           Bandar-e-amirabad
# 19      99309                        Amol
# 20      99348                       Kojur
# 21      99357                     Baladeh
# 22      99360                    Polsefid
# 23      99361                      Alasht

# %% [markdown]
# ### Select Stations
# - Cluster 1 - Sari:40759
# - Cluster 2 - Alasht:99361
# - Cluster 3 - Ramsar:40732

# %%
selected_stations = ["Sari", "Alasht", "Ramsar"]

data = data.query("Station_Name in @selected_stations and Date >= '2006-09' and Date < '2023-10'")

# %%
data
# Out:
#      Station_ID Station_Name    Province  Station_Latitude  Station_Longitude  \
# 856       40732       Ramsar  Mazandaran            36.905             50.684
# 857       40732       Ramsar  Mazandaran            36.905             50.684
# 858       40732       Ramsar  Mazandaran            36.905             50.684
# 859       40732       Ramsar  Mazandaran            36.905             50.684
# 860       40732       Ramsar  Mazandaran            36.905             50.684
# ...         ...          ...         ...               ...                ...
# 5122      99361       Alasht  Mazandaran            36.071             52.843
# 5123      99361       Alasht  Mazandaran            36.071             52.843
# 5124      99361       Alasht  Mazandaran            36.071             52.843
# 5125      99361       Alasht  Mazandaran            36.071             52.843
# 5126      99361       Alasht  Mazandaran            36.071             52.843
#
#       Station_Elevation     Date  Temperature_Maximum  Temperature_Minimum  \
# 856               -20.0  2006-09                 26.5                 20.5
# 857               -20.0  2006-10                 23.8                 18.3
# 858               -20.0  2006-11                 18.2                 10.6
# 859               -20.0  2006-12                 11.9                  5.4
# 860               -20.0  2007-01                 13.0                  4.0
# ...                 ...      ...                  ...                  ...
# 5122             1805.0  2023-05                 21.1                 10.8
# 5123             1805.0  2023-06                 21.4                 13.7
# 5124             1805.0  2023-07                 22.7                 15.4
# 5125             1805.0  2023-08                 25.7                 15.6
# 5126             1805.0  2023-09                 19.9                 11.8
#
#       Temperature  ...  ERA5_SPI_24  ERA5_SPEI_24  GPM_SPI_24  GPM_SPEI_24  \
# 856          23.5  ...          NaN           NaN         NaN          NaN
# 857          21.1  ...          NaN           NaN         NaN          NaN
# 858          14.4  ...          NaN           NaN         NaN          NaN
# 859           8.6  ...          NaN           NaN         NaN          NaN
# 860           8.5  ...          NaN           NaN         NaN          NaN
# ...           ...  ...          ...           ...         ...          ...
# 5122         15.9  ...       -2.054        -2.690      -0.762       -1.916
# 5123         17.6  ...       -1.536        -1.898      -1.708       -1.731
# 5124         19.1  ...       -1.710        -1.969      -0.417       -1.784
# 5125         20.7  ...       -1.185        -1.681      -0.181       -1.813
# 5126         15.8  ...       -1.432        -2.092      -1.746       -1.726
#
#       TRMM_SPI_24  TRMM_SPEI_24  TERRACLIMATE_SPI_24  TERRACLIMATE_SPEI_24  \
# 856           NaN           NaN                  NaN                   NaN
# 857           NaN           NaN                  NaN                   NaN
# 858           NaN           NaN                  NaN                   NaN
# 859           NaN           NaN                  NaN                   NaN
# 860           NaN           NaN                  NaN                   NaN
# ...           ...           ...                  ...                   ...
# 5122          NaN           NaN               -0.129                -1.350
# 5123          NaN           NaN                0.023                -1.054
# 5124          NaN           NaN                0.129                -1.134
# 5125          NaN           NaN                0.083                -1.186
# 5126          NaN           NaN                0.031                -1.129
#
#       PERSIANNCDR_SPI_24  PERSIANNCDR_SPEI_24
# 856                  NaN                  NaN
# 857                  NaN                  NaN
# 858                  NaN                  NaN
# 859                  NaN                  NaN
# 860                  NaN                  NaN
# ...                  ...                  ...
# 5122              -1.939               -1.901
# 5123              -0.646               -1.750
# 5124              -0.934               -1.935
# 5125              -0.545               -1.934
# 5126              -6.196               -2.067
#
# [615 rows x 152 columns]

# %% [markdown]
# ### TaylorDiagram Precip (for each station)

# %%
for sti in selected_stations:
    df = data.query(f"Station_Name == '{sti}'")
    
    model_names = ['ERA5', 'GPM', 'TRMM', 'TERRACLIMATE', 'PERSIANNCDR']
    stddevs = []
    correlations = []
    rmses = []
    std_obss = []

    for model in model_names:
        valid_data = df[['Precipitation', f"{model}_Precipitation"]].dropna()
        observed = valid_data['Precipitation'].values
        modeled = valid_data[f"{model}_Precipitation"].values

        std_model = np.std(modeled)
        std_obs = np.std(observed)
        cor = np.corrcoef(observed, modeled)[0, 1]
        # rmse = np.sqrt(std_model**2 + std_obs**2 - 2 * std_model * std_obs * cor)
        rmse = np.sqrt(np.mean((observed - modeled) ** 2))
        
        stddevs.append(std_model)
        correlations.append(cor)
        rmses.append(rmse)
        std_obss.append(std_obs)

        
    stddevs.insert(0, np.std(df[['Precipitation']].dropna()).values[0])
    rmses.insert(0, 0)
    correlations.insert(0, 1)

    stddevs = np.array(stddevs)
    correlations = np.array(correlations)
    rmses = np.array(rmses)
    std_obss = np.array(std_obss)

    plt.rcParams.update({'font.size': 14})
    fig, ax = plt.subplots(figsize=(8, 8))
    sm.taylor_diagram(
        stddevs, rmses, correlations,
        markerdisplayed='marker',
        markerLabel=['Observed'] + model_names,
        markerColor='blue',
        markerSize=14,
        colCOR='lightblue',
        colrms='lightgreen',
        colstd='black',
        styleCOR='-',
        widthCOR=1,
        titleOBS='Observed',
        # styleOBS='-',
        colOBS='red',
        labelrms="RMSE",
        markerobs = 'o'
    )
    # plt.legend(loc="upper right")
    plt.title(f"{sti}")
    plt.show()
# Out:
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:4109: FutureWarning:
#
# The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:4109: FutureWarning:
#
# The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:4109: FutureWarning:
#
# The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)

# %% [markdown]
# ### Calculate Model Evaluator

# %%
from utils.model_evaluator import ModelEvaluator
for pr_model in ['ERA5', 'GPM', 'TRMM', 'TERRACLIMATE', 'PERSIANNCDR']:
    for sid, df in data.query("Station_Name in @selected_stations").groupby(by='Station_Name'):
        print(f"\nMetrics for Station ID: {sid} and Precip Model: {pr_model}")
        ModelEvaluator(df, 'Precipitation', f'{pr_model}_Precipitation').display_metrics()
# Out:
# Metrics for Station ID: Alasht and Precip Model: ERA5
# Model Performance Metrics:
# Mean Absolute Error (MAE): 60.0964
# Mean Squared Error (MSE): 5994.0464
# Root Mean Squared Error (RMSE): 77.4212
# R-squared (R2): -6.5367
# Explained Variance Score: -2.1649
# Willmott's Index of Agreement (WI): 0.2822
# Nash–Sutcliffe Efficiency (NS): -6.5367
# Mean Absolute Deviation (MAD): 60.0964
#
# Metrics for Station ID: Ramsar and Precip Model: ERA5
# Model Performance Metrics:
# Mean Absolute Error (MAE): 64.1668
# Mean Squared Error (MSE): 7181.7893
# Root Mean Squared Error (RMSE): 84.7454
# R-squared (R2): 0.4130
# Explained Variance Score: 0.5637
# Willmott's Index of Agreement (WI): 0.5784
# Nash–Sutcliffe Efficiency (NS): 0.4130
# Mean Absolute Deviation (MAD): 64.1668
#
# Metrics for Station ID: Sari and Precip Model: ERA5
# Model Performance Metrics:
# Mean Absolute Error (MAE): 24.7196
# Mean Squared Error (MSE): 1009.4705
# Root Mean Squared Error (RMSE): 31.7722
# R-squared (R2): 0.5783
# Explained Variance Score: 0.6214
# Willmott's Index of Agreement (WI): 0.6496
# Nash–Sutcliffe Efficiency (NS): 0.5783
# Mean Absolute Deviation (MAD): 24.7196
#
# Metrics for Station ID: Alasht and Precip Model: GPM
# Model Performance Metrics:
# Mean Absolute Error (MAE): 14.1765
# Mean Squared Error (MSE): 339.1974
# Root Mean Squared Error (RMSE): 18.4173
# R-squared (R2): 0.5735
# Explained Variance Score: 0.5835
# Willmott's Index of Agreement (WI): 0.6604
# Nash–Sutcliffe Efficiency (NS): 0.5735
# Mean Absolute Deviation (MAD): 14.1765
#
# Metrics for Station ID: Ramsar and Precip Model: GPM
# Model Performance Metrics:
# Mean Absolute Error (MAE): 45.7956
# Mean Squared Error (MSE): 6871.8676
# Root Mean Squared Error (RMSE): 82.8967
# R-squared (R2): 0.4383
# Explained Variance Score: 0.5121
# Willmott's Index of Agreement (WI): 0.6332
# Nash–Sutcliffe Efficiency (NS): 0.4383
# Mean Absolute Deviation (MAD): 45.7956
#
# Metrics for Station ID: Sari and Precip Model: GPM
# Model Performance Metrics:
# Mean Absolute Error (MAE): 16.7111
# Mean Squared Error (MSE): 537.4797
# Root Mean Squared Error (RMSE): 23.1836
# R-squared (R2): 0.7755
# Explained Variance Score: 0.8037
# Willmott's Index of Agreement (WI): 0.7548
# Nash–Sutcliffe Efficiency (NS): 0.7755
# Mean Absolute Deviation (MAD): 16.7111
#
# Metrics for Station ID: Alasht and Precip Model: TRMM
# Model Performance Metrics:
# Mean Absolute Error (MAE): 18.4312
# Mean Squared Error (MSE): 564.9479
# Root Mean Squared Error (RMSE): 23.7686
# R-squared (R2): 0.3079
# Explained Variance Score: 0.3182
# Willmott's Index of Agreement (WI): 0.6203
# Nash–Sutcliffe Efficiency (NS): 0.3079
# Mean Absolute Deviation (MAD): 18.4312
#
# Metrics for Station ID: Ramsar and Precip Model: TRMM
# Model Performance Metrics:
# Mean Absolute Error (MAE): 49.8114
# Mean Squared Error (MSE): 6934.1852
# Root Mean Squared Error (RMSE): 83.2718
# R-squared (R2): 0.4575
# Explained Variance Score: 0.5843
# Willmott's Index of Agreement (WI): 0.6246
# Nash–Sutcliffe Efficiency (NS): 0.4575
# Mean Absolute Deviation (MAD): 49.8114
#
# Metrics for Station ID: Sari and Precip Model: TRMM
# Model Performance Metrics:
# Mean Absolute Error (MAE): 20.2871
# Mean Squared Error (MSE): 788.7424
# Root Mean Squared Error (RMSE): 28.0846
# R-squared (R2): 0.6892
# Explained Variance Score: 0.7701
# Willmott's Index of Agreement (WI): 0.7222
# Nash–Sutcliffe Efficiency (NS): 0.6892
# Mean Absolute Deviation (MAD): 20.2871
#
# Metrics for Station ID: Alasht and Precip Model: TERRACLIMATE
# Model Performance Metrics:
# Mean Absolute Error (MAE): 24.8476
# Mean Squared Error (MSE): 1040.0020
# Root Mean Squared Error (RMSE): 32.2491
# R-squared (R2): -0.3077
# Explained Variance Score: 0.3484
# Willmott's Index of Agreement (WI): 0.4691
# Nash–Sutcliffe Efficiency (NS): -0.3077
# Mean Absolute Deviation (MAD): 24.8476
#
# Metrics for Station ID: Ramsar and Precip Model: TERRACLIMATE
# Model Performance Metrics:
# Mean Absolute Error (MAE): 49.4880
# Mean Squared Error (MSE): 7252.9930
# Root Mean Squared Error (RMSE): 85.1645
# R-squared (R2): 0.4071
# Explained Variance Score: 0.4510
# Willmott's Index of Agreement (WI): 0.6413
# Nash–Sutcliffe Efficiency (NS): 0.4071
# Mean Absolute Deviation (MAD): 49.4880
#
# Metrics for Station ID: Sari and Precip Model: TERRACLIMATE
# Model Performance Metrics:
# Mean Absolute Error (MAE): 28.7825
# Mean Squared Error (MSE): 1610.0366
# Root Mean Squared Error (RMSE): 40.1253
# R-squared (R2): 0.3274
# Explained Variance Score: 0.4036
# Willmott's Index of Agreement (WI): 0.6307
# Nash–Sutcliffe Efficiency (NS): 0.3274
# Mean Absolute Deviation (MAD): 28.7825
#
# Metrics for Station ID: Alasht and Precip Model: PERSIANNCDR
# Model Performance Metrics:
# Mean Absolute Error (MAE): 21.2667
# Mean Squared Error (MSE): 875.7478
# Root Mean Squared Error (RMSE): 29.5930
# R-squared (R2): -0.1011
# Explained Variance Score: 0.1092
# Willmott's Index of Agreement (WI): 0.5318
# Nash–Sutcliffe Efficiency (NS): -0.1011
# Mean Absolute Deviation (MAD): 21.2667
#
# Metrics for Station ID: Ramsar and Precip Model: PERSIANNCDR
# Model Performance Metrics:
# Mean Absolute Error (MAE): 72.7496
# Mean Squared Error (MSE): 14724.8228
# Root Mean Squared Error (RMSE): 121.3459
# R-squared (R2): -0.2036
# Explained Variance Score: 0.1552
# Willmott's Index of Agreement (WI): 0.4929
# Nash–Sutcliffe Efficiency (NS): -0.2036
# Mean Absolute Deviation (MAD): 72.7496
#
# Metrics for Station ID: Sari and Precip Model: PERSIANNCDR
# Model Performance Metrics:
# Mean Absolute Error (MAE): 37.2648
# Mean Squared Error (MSE): 2610.7454
# Root Mean Squared Error (RMSE): 51.0955
# R-squared (R2): -0.0907
# Explained Variance Score: 0.3274
# Willmott's Index of Agreement (WI): 0.5052
# Nash–Sutcliffe Efficiency (NS): -0.0907
# Mean Absolute Deviation (MAD): 37.2648

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

for st in selected_stations:
    station_data = data.query("Station_Name == @st")[['Date', 'Precipitation', 'GPM_Precipitation']].dropna()

    fig = px.scatter(
        station_data,
        x='Precipitation',
        y='GPM_Precipitation',
        labels={
            "Precipitation": f"{st}<br>Observed Precipitation (mm)",
            "GPM_Precipitation": "GPM Estimated Precipitation (mm)"
        },
        opacity=0.7,
        color_discrete_sequence=["black"],  # make points black
    )

    # Make scatter markers bigger
    fig.update_traces(marker=dict(size=8, color="black"))

    # Equal axis limits
    max_limit = max(station_data['Precipitation'].max(),
                    station_data['GPM_Precipitation'].max()) + 50
    
    # Equal ticks
    tick_vals = np.arange(0, max_limit + 1, 50)

    fig.update_layout(
        xaxis=dict(range=[0, max_limit], tickvals=tick_vals),
        yaxis=dict(range=[0, max_limit], tickvals=tick_vals),
        width=600,
        height=600,
        title=None,
        margin=dict(l=20, r=20, t=20, b=20),
    )
    fig.update_yaxes(scaleanchor="x", scaleratio=1)

    # Add 1:1 line (hidden from legend)
    fig.add_trace(go.Scatter(
        x=[0, max_limit],
        y=[0, max_limit],
        mode="lines",
        line=dict(color="red", dash="dash"),
        showlegend=False
    ))

    fig.show()
