# %% [markdown]
# # Import Libraries

# %%
import sys
import sqlite3
import warnings

import pandas as pd
import numpy as np
import shap
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score, classification_report, confusion_matrix
from sklearn.feature_selection import RFECV


warnings.filterwarnings('ignore')
np.random.seed(42)

# %% [markdown]
# # Load Database

# %%
sys.path.append('/home/pooya/w/DroughtMonitoringIran/')

DATABASE_PATH = "./database/database.db"

conn = sqlite3.connect(DATABASE_PATH)

data = pd.read_sql(sql='SELECT * FROM data', con=conn)

conn.close()

# %% [markdown]
# # Select Columns and Rows

# %%
# Select Drought Index and Period
di = 'SPEI'
di_scale = 6

# Select Stations
# selected_stations = ['Ramsar', 'Nowshahr', 'Siahbisheh', 'Kiyasar', 'Kojur', 'Baladeh', 'Alasht', 'Babolsar', 'Gharakhil', 'Sari', 'Sari (dasht-e-naz airport)', 'Galugah', 'Bandar-e-amirabad', 'Amol', 'Polsefid']
selected_stations = ['Ramsar', 'Nowshahr']
# selected_stations = ['Siahbisheh', 'Kiyasar', 'Kojur', 'Baladeh', 'Alasht']
# selected_stations = ['Babolsar', 'Gharakhil', 'Sari', 'Sari (dasht-e-naz airport)', 'Galugah', 'Bandar-e-amirabad', 'Amol', 'Polsefid']

# Select Columns
selected_columns = [
    'Station_Name', 'Station_ID',
    'Station_Latitude', 'Station_Longitude', 'Station_Elevation',
    'Date',
    f'{di}_{di_scale}',
    f'GPM_{di}_{di_scale}',
    f'ERA5_{di}_{di_scale}',
    'ERA5_Precipitation',
    'GPM_Precipitation',
    'TRMM_Precipitation',
    'TERRACLIMATE_Precipitation',
    'PERSIANNCDR_Precipitation',
    'PET_MOD16A2GF',
    'NDVI', 'EVI',
    'LSTDay', 'LSTNight', 'LST',
    'PCI_GPM', 'PCI_ERA5',
    'VCI', 'TCI', 'VHI',
    'CI_GPM', 'CI_ERA5',
]

# Select Start and End Date
start_date = '2006-09'
end_date = '2023-10'

# %% [markdown]
# # Filter Data

# %%
df = data\
    .filter(items=selected_columns)\
        .query("Station_Name in @selected_stations and Date >= @start_date and Date < @end_date")

# %% [markdown]
# # Add Some Columns

# %%
# Date, Year, Month
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# SPI and SPEI Class
df[f'{di}_{di_scale}_Class'] = pd.cut(df[f'{di}_{di_scale}'], bins=[-10, -2, -1.5, -1, 1, 1.5, 2, 10], labels=['ED', 'SD', 'MD', 'NN', 'MW', 'VW', 'EW'])

# Month Sin & Cos
df['Month_sin'] = np.sin(2 * np.pi * df['Month'] / 12)
df['Month_cos'] = np.cos(2 * np.pi * df['Month'] / 12)
        
# LST Diff
df['LST_Diff'] = df['LSTDay'] - df['LSTNight']

# Convert to Category
df['Station_ID'] = df['Station_ID'].astype('category')
df['Year'] = df['Year'].astype('category')
df['Month'] = df['Month'].astype('category')
df[f'{di}_{di_scale}_Class'] = df[f'{di}_{di_scale}_Class'].astype('category')

# %%
df.dropna(inplace=True)
df.sort_values(by=['Station_ID', 'Year', 'Month'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
selected_columns_lag_roll = [
    'ERA5_Precipitation',
    'GPM_Precipitation',
    'TRMM_Precipitation',
    'TERRACLIMATE_Precipitation',
    'PERSIANNCDR_Precipitation',
    f'GPM_{di}_{di_scale}',
    f'ERA5_{di}_{di_scale}',
    'PET_MOD16A2GF',
    'NDVI', 'EVI',
    'LSTDay', 'LSTNight', 'LST',
    'PCI_GPM', 'PCI_ERA5',
    'VCI', 'TCI', 'VHI',
    'CI_GPM', 'CI_ERA5',
]

# Add Lag
for lag in range(1, 4):
    for col in selected_columns_lag_roll:
        df[f'{col}_lag_{lag}'] = df.groupby('Station_ID', observed=False)[col].shift(lag)


# Add Mean and Std Roll
for r in [3]:
    for col in selected_columns_lag_roll:
        df[f'{col}_roll_mean_{r}'] = df.groupby('Station_ID', observed=False)[col].transform(lambda x: x.rolling(window=r, min_periods=1).mean())
        df[f'{col}_roll_std_{r}'] = df.groupby('Station_ID', observed=False)[col].transform(lambda x: x.rolling(window=r, min_periods=1).std())

# %% [markdown]
# # Remove all NA

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Station-wise Standardization

# %%
# Define columns to exclude from features
EXCLUDE_COLS = ['Station_Name', 'Station_ID', 'Date', f'{di}_{di_scale}_Class', f'{di}_{di_scale}', 'Year', 'Month']
FEATURES = [col for col in df.columns if col not in EXCLUDE_COLS]

# Station-wise standardization
df_scaled = df.copy()
for station in df_scaled['Station_Name'].unique():
    station_mask = df_scaled['Station_Name'] == station
    scaler = StandardScaler()
    df_scaled.loc[station_mask, FEATURES] = scaler.fit_transform(df_scaled.loc[station_mask, FEATURES])


class_counts = df_scaled[f'{di}_{di_scale}_Class'].value_counts()
classes_to_remove = class_counts[class_counts < 2].index

if not classes_to_remove.empty:
    print(f"Removing classes with fewer than 2 samples: {classes_to_remove.tolist()}")
    
    # Filter the dataframe to exclude these rare classes
    df_filtered = df_scaled[~df_scaled[f'{di}_{di_scale}_Class'].isin(classes_to_remove)].copy()
    
    # Redefine X and y from the filtered dataframe
    X = df_filtered[FEATURES]
    y = df_filtered[f'{di}_{di_scale}_Class']
    
    print(f"Data shape after removing rare classes: {X.shape}")
    print("\n--- Final Class Distribution ---")
    print(y.value_counts())
else:
    print("No classes with fewer than 2 samples found.")
    X = df_scaled[FEATURES]
    y = df_scaled[f'{di}_{di_scale}_Class']

# Encode the target variable
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.30,
    random_state=42,
    stratify=y_encoded
)

print(f"Target Classes: {le.classes_}")
print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")
# Out:
# Removing classes with fewer than 2 samples: ['EW']
# Data shape after removing rare classes: (303, 126)
#
# --- Final Class Distribution ---
# SPEI_6_Class
# NN    199
# MD     37
# MW     31
# SD     20
# VW     13
# ED      3
# EW      0
# Name: count, dtype: int64
# Target Classes: ['ED' 'MD' 'MW' 'NN' 'SD' 'VW']
# Training set shape: (212, 126)
# Testing set shape: (91, 126)

# %% [markdown]
# # Feature Selection with RFECV

# %%
# The estimator that will be used by RFECV
estimator = RandomForestClassifier(
    random_state=42, 
    n_jobs=-1
)

# The RFECV object
rfecv = RFECV(
    estimator=estimator,
    step=1,
    cv=StratifiedKFold(5),
    scoring='f1_macro',
    n_jobs=-1
)

# Fit RFECV on the training data
rfecv.fit(X_train, y_train)

print(f"Optimal number of features found: {rfecv.n_features_}")

# Get the final selected features
final_features = X_train.columns[rfecv.support_]
print(f"Selected features: {final_features.tolist()}")

# --- Plot Feature Importances ---
# The `rfecv.estimator_` attribute is the model trained on the full set of features
# during the last step of the cross-validation process. We can use its feature importances.
importances = rfecv.estimator_.feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': final_features,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Plot only the selected features
selected_feature_importances = feature_importance_df[feature_importance_df['Feature'].isin(final_features)]

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=selected_feature_importances)
plt.title('Feature Importances for Selected Features (from RFECV)')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()


# Update training and testing sets with selected features
X_train_final = X_train[final_features]
X_test_final = X_test[final_features]
# Out:
# Optimal number of features found: 16
# Selected features: ['GPM_SPEI_6', 'ERA5_SPEI_6', 'GPM_Precipitation', 'TRMM_Precipitation', 'LSTDay_lag_3', 'VHI_lag_3', 'TRMM_Precipitation_roll_mean_3', 'GPM_SPEI_6_roll_mean_3', 'GPM_SPEI_6_roll_std_3', 'EVI_roll_std_3', 'LSTDay_roll_std_3', 'PCI_GPM_roll_mean_3', 'PCI_ERA5_roll_mean_3', 'VCI_roll_mean_3', 'CI_ERA5_roll_mean_3', 'CI_ERA5_roll_std_3']

# %% [markdown]
# # Hyperparameter Tuning with Optuna

# %%
def objective(trial):
    """Define the objective function for Optuna to optimize."""
    params = {
        'hidden_layer_sizes': (trial.suggest_int('n_units_l1', 50, 200), trial.suggest_int('n_units_l2', 50, 200)),
        'alpha': trial.suggest_float('alpha', 1e-5, 1e-1, log=True),
        'learning_rate_init': trial.suggest_float('learning_rate_init', 1e-4, 1e-2, log=True),
        'max_iter': 1000,
        'random_state': 42
    }

    model = MLPClassifier(**params)

    # Stratified K-Fold Cross-Validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    f1_scores = []
    
    for train_idx, val_idx in skf.split(X_train_final, y_train):
        X_train_fold, X_val_fold = X_train_final.iloc[train_idx], X_train_final.iloc[val_idx]
        y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]
        
        model.fit(X_train_fold, y_train_fold)
        preds = model.predict(X_val_fold)
        f1_scores.append(f1_score(y_val_fold, preds, average='macro'))
        
    return np.mean(f1_scores)

# Create a study object and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, timeout=600) # 50 trials or 10 minutes

print(f"Best trial found: {study.best_trial.number}")
print(f"Best Macro-F1 Score: {study.best_value}")
print("Best Hyperparameters:")
print(study.best_params)
# Out:
# [I 2025-08-22 21:26:03,422] A new study created in memory with name: no-name-7a04e308-5191-4165-afec-6605fe3d9d6c
# [I 2025-08-22 21:26:06,016] Trial 0 finished with value: 0.28126564028034157 and parameters: {'n_units_l1': 120, 'n_units_l2': 65, 'alpha': 3.110021978239874e-05, 'learning_rate_init': 0.00042454350119183515}. Best is trial 0 with value: 0.28126564028034157.
# [I 2025-08-22 21:26:15,612] Trial 1 finished with value: 0.26921567816280856 and parameters: {'n_units_l1': 88, 'n_units_l2': 184, 'alpha': 7.06290464713933e-05, 'learning_rate_init': 0.0004318657653826497}. Best is trial 0 with value: 0.28126564028034157.
# [I 2025-08-22 21:26:16,736] Trial 2 finished with value: 0.3587109577895192 and parameters: {'n_units_l1': 148, 'n_units_l2': 53, 'alpha': 1.1163053364552938e-05, 'learning_rate_init': 0.0015280591719355407}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21
. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:27:57,051] Trial 49 finished with value: 0.3117476215161655 and parameters: {'n_units_l1': 129, 'n_units_l2': 108, 'alpha': 0.009190069281166394, 'learning_rate_init': 0.0009079445295127567}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:27:59,373] Trial 50 finished with value: 0.3106761397116677 and parameters: {'n_units_l1': 183, 'n_units_l2': 124, 'alpha': 1.4815393687400692e-05, 'learning_rate_init': 0.0020580331607031603}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:03,349] Trial 51 finished with value: 0.2638222397034623 and parameters: {'n_units_l1': 152, 'n_units_l2': 135, 'alpha': 0.0033489204804344115, 'learning_rate_init': 0.0014932531372193972}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:05,355] Trial 52 finished with value: 0.3246003654096838 and parameters: {'n_units_l1': 161, 'n_units_l2': 189, 'alpha': 0.0011657881418657495, 'learning_rate_init': 0.0024525959831790374}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:06,649] Trial 53 finished with value: 0.273939482788167 and parameters: {'n_units_l1': 169, 'n_units_l2': 50, 'alpha': 0.0006438084441664334, 'learning_rate_init': 0.0011736210794028765}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:07,879] Trial 54 finished with value: 0.30455207476712853 and parameters: {'n_units_l1': 177, 'n_units_l2': 92, 'alpha': 0.00019801794447818778, 'learning_rate_init': 0.0028121465396300158}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:09,525] Trial 55 finished with value: 0.3253672582321873 and parameters: {'n_units_l1': 155, 'n_units_l2': 151, 'alpha': 0.0010508923936804065, 'learning_rate_init': 0.0021795869611643866}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:10,441] Trial 56 finished with value: 0.32281038305342646 and parameters: {'n_units_l1': 145, 'n_units_l2': 134, 'alpha': 0.00034700248357659127, 'learning_rate_init': 0.0037700647556302845}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:11,129] Trial 57 finished with value: 0.26533068474763255 and parameters: {'n_units_l1': 199, 'n_units_l2': 74, 'alpha': 4.292282382442784e-05, 'learning_rate_init': 0.005801369816210428}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:11,999] Trial 58 finished with value: 0.28339326071830306 and parameters: {'n_units_l1': 73, 'n_units_l2': 80, 'alpha': 0.0043920230523006015, 'learning_rate_init': 0.001615482978754554}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:17,584] Trial 59 finished with value: 0.26814382998604314 and parameters: {'n_units_l1': 191, 'n_units_l2': 62, 'alpha': 0.03658298564005048, 'learning_rate_init': 0.0009812072661775733}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:21,387] Trial 60 finished with value: 0.29475850643558044 and parameters: {'n_units_l1': 129, 'n_units_l2': 167, 'alpha': 0.00010815911033206917, 'learning_rate_init': 0.0007839205425599024}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:24,554] Trial 61 finished with value: 0.29071093310535767 and parameters: {'n_units_l1': 158, 'n_units_l2': 150, 'alpha': 0.0008423979727560422, 'learning_rate_init': 0.002154805450115873}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:26,882] Trial 62 finished with value: 0.2770874180884634 and parameters: {'n_units_l1': 151, 'n_units_l2': 120, 'alpha': 0.0005429007822196287, 'learning_rate_init': 0.0018683762975150256}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:28,025] Trial 63 finished with value: 0.3096745610373599 and parameters: {'n_units_l1': 122, 'n_units_l2': 130, 'alpha': 0.001370009398801697, 'learning_rate_init': 0.0031408692498305414}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:30,667] Trial 64 finished with value: 0.2861608571457649 and parameters: {'n_units_l1': 155, 'n_units_l2': 141, 'alpha': 0.0020786996441601365, 'learning_rate_init': 0.001386271892755917}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:32,704] Trial 65 finished with value: 0.2844357872977373 and parameters: {'n_units_l1': 166, 'n_units_l2': 118, 'alpha': 1.3518965276929692e-05, 'learning_rate_init': 0.0023418758772091115}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:34,698] Trial 66 finished with value: 0.27725028838788507 and parameters: {'n_units_l1': 143, 'n_units_l2': 147, 'alpha': 2.2043257443422133e-05, 'learning_rate_init': 0.0015991789738207783}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:36,145] Trial 67 finished with value: 0.26359933911598815 and parameters: {'n_units_l1': 136, 'n_units_l2': 184, 'alpha': 0.00035654967605459485, 'learning_rate_init': 0.004937501247126509}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:38,188] Trial 68 finished with value: 0.310589433957855 and parameters: {'n_units_l1': 101, 'n_units_l2': 104, 'alpha': 0.0007694950985084215, 'learning_rate_init': 0.006992380624658155}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:40,680] Trial 69 finished with value: 0.3126018307195827 and parameters: {'n_units_l1': 112, 'n_units_l2': 154, 'alpha': 0.0029216695546488737, 'learning_rate_init': 0.0011955345995583897}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:42,874] Trial 70 finished with value: 0.2777372157315935 and parameters: {'n_units_l1': 176, 'n_units_l2': 129, 'alpha': 0.0011314877167745928, 'learning_rate_init': 0.003752048570103209}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:44,462] Trial 71 finished with value: 0.31565502358678094 and parameters: {'n_units_l1': 161, 'n_units_l2': 188, 'alpha': 0.001184142985113576, 'learning_rate_init': 0.0024268460109437315}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:47,027] Trial 72 finished with value: 0.3077322080917407 and parameters: {'n_units_l1': 189, 'n_units_l2': 192, 'alpha': 0.0004370273967734851, 'learning_rate_init': 0.002687026703322369}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:51,721] Trial 73 finished with value: 0.28113680712171485 and parameters: {'n_units_l1': 163, 'n_units_l2': 193, 'alpha': 0.0017301326788315276, 'learning_rate_init': 0.002176224393276901}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:53,976] Trial 74 finished with value: 0.2907242602039305 and parameters: {'n_units_l1': 146, 'n_units_l2': 175, 'alpha': 0.00027925721941399184, 'learning_rate_init': 0.0019435457187084067}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:28:58,956] Trial 75 finished with value: 0.2853135625549419 and parameters: {'n_units_l1': 133, 'n_units_l2': 200, 'alpha': 3.859841586432012e-05, 'learning_rate_init': 0.0016329871438046251}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:01,614] Trial 76 finished with value: 0.3013531073446328 and parameters: {'n_units_l1': 140, 'n_units_l2': 181, 'alpha': 0.0009429135558230707, 'learning_rate_init': 0.0025921552141889236}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:02,236] Trial 77 finished with value: 0.30597574722571397 and parameters: {'n_units_l1': 86, 'n_units_l2': 68, 'alpha': 0.00014119171560188305, 'learning_rate_init': 0.003043311750685343}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:03,479] Trial 78 finished with value: 0.32161834629995756 and parameters: {'n_units_l1': 169, 'n_units_l2': 58, 'alpha': 0.0006200290005282626, 'learning_rate_init': 0.001338618129346592}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:05,596] Trial 79 finished with value: 0.29038515624987415 and parameters: {'n_units_l1': 155, 'n_units_l2': 194, 'alpha': 1.2584211786338912e-05, 'learning_rate_init': 0.0017601188044817637}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:07,525] Trial 80 finished with value: 0.31047753160813796 and parameters: {'n_units_l1': 76, 'n_units_l2': 166, 'alpha': 2.186205615816618e-05, 'learning_rate_init': 0.0011039582954211298}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:08,588] Trial 81 finished with value: 0.2889148147733135 and parameters: {'n_units_l1': 149, 'n_units_l2': 143, 'alpha': 0.00036138377098605577, 'learning_rate_init': 0.003475100766006985}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:09,178] Trial 82 finished with value: 0.30161351572162615 and parameters: {'n_units_l1': 142, 'n_units_l2': 54, 'alpha': 0.00022927868659414026, 'learning_rate_init': 0.003695320714353027}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:10,175] Trial 83 finished with value: 0.2656144707700216 and parameters: {'n_units_l1': 147, 'n_units_l2': 132, 'alpha': 0.0004731573362422617, 'learning_rate_init': 0.004069090633946969}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:11,274] Trial 84 finished with value: 0.29053169627307557 and parameters: {'n_units_l1': 158, 'n_units_l2': 137, 'alpha': 0.001507800437554088, 'learning_rate_init': 0.004721769638600971}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:12,058] Trial 85 finished with value: 0.3127133870385287 and parameters: {'n_units_l1': 64, 'n_units_l2': 117, 'alpha': 0.0007105921722787873, 'learning_rate_init': 0.002254875645540922}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:13,609] Trial 86 finished with value: 0.2724477051533591 and parameters: {'n_units_l1': 179, 'n_units_l2': 173, 'alpha': 0.0003178039919626335, 'learning_rate_init': 0.002884996147828032}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:15,730] Trial 87 finished with value: 0.281407893818123 and parameters: {'n_units_l1': 97, 'n_units_l2': 133, 'alpha': 6.726998180604325e-05, 'learning_rate_init': 0.002040725584884949}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:18,144] Trial 88 finished with value: 0.270428477261222 and parameters: {'n_units_l1': 153, 'n_units_l2': 160, 'alpha': 0.001149388955613044, 'learning_rate_init': 0.0014225093920961056}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:19,966] Trial 89 finished with value: 0.2944818043344645 and parameters: {'n_units_l1': 108, 'n_units_l2': 66, 'alpha': 0.0024825321752344007, 'learning_rate_init': 0.0005977032180106448}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:21,285] Trial 90 finished with value: 0.31018328049193344 and parameters: {'n_units_l1': 124, 'n_units_l2': 127, 'alpha': 0.003975691748956162, 'learning_rate_init': 0.0026553087044898726}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:23,111] Trial 91 finished with value: 0.2860360738898967 and parameters: {'n_units_l1': 160, 'n_units_l2': 97, 'alpha': 1.0171675012380741e-05, 'learning_rate_init': 0.0017703865484596686}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:24,462] Trial 92 finished with value: 0.2724931918700587 and parameters: {'n_units_l1': 132, 'n_units_l2': 95, 'alpha': 1.7718427641898637e-05, 'learning_rate_init': 0.002450572014961255}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:28,483] Trial 93 finished with value: 0.307905529953917 and parameters: {'n_units_l1': 104, 'n_units_l2': 89, 'alpha': 3.345603549557253e-05, 'learning_rate_init': 0.0017319985492943576}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:29,095] Trial 94 finished with value: 0.28063670707166233 and parameters: {'n_units_l1': 69, 'n_units_l2': 112, 'alpha': 1.199768607480964e-05, 'learning_rate_init': 0.003267232575614455}. Best is trial 2 with value: 0.3587109577895192.
# [I 2025-08-22 21:29:30,768] Trial 95 finished with value: 0.3618153236271659 and parameters: {'n_units_l1': 115, 'n_units_l2': 103, 'alpha': 2.5354850085138073e-05, 'learning_rate_init': 0.001254004596116478}. Best is trial 95 with value: 0.3618153236271659.
# [I 2025-08-22 21:29:32,252] Trial 96 finished with value: 0.29083558215973687 and parameters: {'n_units_l1': 92, 'n_units_l2': 108, 'alpha': 2.6388211318666635e-05, 'learning_rate_init': 0.000999356173013604}. Best is trial 95 with value: 0.3618153236271659.
# [I 2025-08-22 21:29:33,364] Trial 97 finished with value: 0.304250882324668 and parameters: {'n_units_l1': 115, 'n_units_l2': 81, 'alpha': 5.382806350532097e-05, 'learning_rate_init': 0.0015228527418892693}. Best is trial 95 with value: 0.3618153236271659.
# [I 2025-08-22 21:29:35,517] Trial 98 finished with value: 0.29609999301257106 and parameters: {'n_units_l1': 167, 'n_units_l2': 76, 'alpha': 0.0008859102113416156, 'learning_rate_init': 0.001187075597825989}. Best is trial 95 with value: 0.3618153236271659.
# [I 2025-08-22 21:29:36,494] Trial 99 finished with value: 0.2735433965430413 and parameters: {'n_units_l1': 139, 'n_units_l2': 125, 'alpha': 8.437204981309753e-05, 'learning_rate_init': 0.003978265040491933}. Best is trial 95 with value: 0.3618153236271659.
# Best trial found: 95
# Best Macro-F1 Score: 0.3618153236271659
# Best Hyperparameters:
# {'n_units_l1': 115, 'n_units_l2': 103, 'alpha': 2.5354850085138073e-05, 'learning_rate_init': 0.001254004596116478}

# %% [markdown]
# # Model Training & Evaluation

# %%
# Get best hyperparameters
best_params = study.best_params
best_params['hidden_layer_sizes'] = (best_params.pop('n_units_l1'), best_params.pop('n_units_l2'))
best_params['random_state'] = 42
best_params['max_iter'] = 1000

# Train the final model
final_model = MLPClassifier(**best_params)
final_model.fit(X_train_final, y_train)

# Make predictions on the test set
y_pred = final_model.predict(X_test_final)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
macro_f1 = f1_score(y_test, y_pred, average='macro')
kappa = cohen_kappa_score(y_test, y_pred)

print(f"Overall Accuracy: {accuracy:.4f}")
print(f"Macro-F1 Score: {macro_f1:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))


# --- Plot Confusion Matrix ---
print("\n--- Plotting Confusion Matrix ---")
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# Overall Accuracy: 0.5934
# Macro-F1 Score: 0.2731
# Cohen's Kappa: 0.1500
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           ED       0.00      0.00      0.00         1
#           MD       0.50      0.36      0.42        11
#           MW       0.33      0.22      0.27         9
#           NN       0.68      0.78      0.73        60
#           SD       0.33      0.17      0.22         6
#           VW       0.00      0.00      0.00         4
#
#     accuracy                           0.59        91
#    macro avg       0.31      0.26      0.27        91
# weighted avg       0.56      0.59      0.57        91
#
#
# --- Plotting Confusion Matrix ---

# %% [markdown]
# # Explainability with SHAP

# %%
# Use SHAP to explain the output of the final model.
# NOTE: For non-tree models like MLP, we use KernelExplainer, which can be slower.
print("\n--- 5. SHAP Analysis and Reporting ---")

# Create a summary of the training data for the SHAP explainer background
# This is a performance optimization for KernelExplainer
background_data = shap.kmeans(X_train_final, 50) # Summarize with 50 clusters

# Create SHAP KernelExplainer for the final model
explainer = shap.KernelExplainer(final_model.predict_proba, background_data)
# Explain a smaller subset of the test data for performance
shap_values = explainer.shap_values(X_test_final.sample(50, random_state=42)) 

# SHAP Summary Plot (Bar)
print("\nGenerating SHAP Summary Bar Plot...")
plt.figure()
shap.summary_plot(shap_values, X_test_final, plot_type="bar", class_names=le.classes_, show=False)
plt.title("SHAP Summary Plot (Global Feature Importance)")
plt.tight_layout()
plt.show()

# SHAP Summary Plot (Beeswarm)
print("\nGenerating SHAP Summary Beeswarm Plot...")
plt.figure()
shap.summary_plot(shap_values, X_test_final, class_names=le.classes_, show=False)
plt.title("SHAP Summary Plot (Beeswarm)")
plt.tight_layout()
plt.show()

# SHAP Dependence Plot
print("\nGenerating SHAP Dependence Plot for the top feature...")
# Get the name of the top feature from our importance dataframe
top_feature = feature_importance_df['Feature'].iloc[0]

# To avoid errors, explicitly define the interaction feature as the second most important one.
if len(feature_importance_df) > 1:
    interaction_feature = feature_importance_df['Feature'].iloc[1]
else:
    interaction_feature = None # No other feature to interact with

# We will plot the dependence for the first class (index 0)
class_index_to_plot = 0
class_name_to_plot = le.classes_[class_index_to_plot]

# For multi-class KernelExplainer, shap_values is a list of arrays.
# We need to select the shap_values for the class we want to plot
shap_values_for_class = shap_values[class_index_to_plot]


plt.figure()
shap.dependence_plot(
    top_feature, 
    shap_values_for_class,
    X_test_final, 
    show=False,
    interaction_index=interaction_feature
)
plt.title(f"SHAP Dependence Plot for '{top_feature}' (for class: {class_name_to_plot})")
plt.tight_layout()
plt.show()
# Out:
# --- 5. SHAP Analysis and Reporting ---
# 100%|██████████| 50/50 [00:16<00:00,  3.12it/s]
# Generating SHAP Summary Bar Plot...
# Generating SHAP Summary Beeswarm Plot...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 25
#      23 print("\nGenerating SHAP Summary Beeswarm Plot...")
#      24 plt.figure()
# ---> 25 shap.summary_plot(shap_values, X_test_final, class_names=le.classes_, show=False)
#      26 plt.title("SHAP Summary Plot (Beeswarm)")
#      27 plt.tight_layout()
#
# File ~/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/shap/plots/_beeswarm.py:723, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     721 proj_shap_values = shap_values[:, sort_inds[0], sort_inds]
#     722 proj_shap_values[:, 1:] *= 2  # because off diag effects are split in half
# --> 723 summary_legacy(
#     724     proj_shap_values,
#     725     features[:, sort_inds] if features is not None else None,
#     726     feature_names=np.array(feature_names)[sort_inds].tolist(),
#     727     sort=False,
#     728     show=False,
#     729     color_bar=False,
#     730     plot_size=None,
#     731     max_display=max_display,
#     732 )
#     733 plt.xlim((slow, shigh))
#     734 plt.xlabel("")
#
# File ~/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/shap/plots/_beeswarm.py:841, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     838 if vmin > vmax:  # fixes rare numerical precision issues
#     839     vmin = vmax
# --> 841 assert features.shape[0] == len(shaps), "Feature and SHAP matrices must have the same number of rows!"
#     843 # plot the nan values in the interaction feature as grey
#     844 nan_mask = np.isnan(values)
#
# AssertionError: Feature and SHAP matrices must have the same number of rows!
