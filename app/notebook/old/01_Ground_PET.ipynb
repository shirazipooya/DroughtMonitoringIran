# %%
import os
import sys
import sqlite3
import numpy as np
import pandas as pd
import geopandas as gp
import plotly.express as px

import pyet

# %%
sys.path.append('/home/pooya/w/DroughtMonitoringIran/')

GEO_DATA_PATH = "./assets/geo_data"
DATABASE_PATH = "./database/database.db"

# %%
conn = sqlite3.connect(DATABASE_PATH)

daily_data = pd.read_sql(sql='SELECT * FROM ground_data_daily', con=conn)
daily_data['Date'] = pd.to_datetime(daily_data['Date'])

monthly_data = pd.read_sql(sql='SELECT * FROM ground_data_monthly', con=conn)

geoinfo = pd.read_sql(sql='SELECT * FROM ground_data_geoinfo', con=conn)

conn.close()

# %%
monthly_data
# Out:
#        Year  Month Province_ID    Province Station_ID Station_Name  \
# 0      1951      1        MASA  Mazandaran      99361       Alasht
# 1      1951      2        MASA  Mazandaran      99361       Alasht
# 2      1951      3        MASA  Mazandaran      99361       Alasht
# 3      1951      4        MASA  Mazandaran      99361       Alasht
# 4      1951      5        MASA  Mazandaran      99361       Alasht
# ...     ...    ...         ...         ...        ...          ...
# 21523  2025      5        MASA  Mazandaran      18332    Tonekabon
# 21524  2025      6        MASA  Mazandaran      18332    Tonekabon
# 21525  2025      7        MASA  Mazandaran      18332    Tonekabon
# 21526  2025      8        MASA  Mazandaran      18332    Tonekabon
# 21527  2025      9        MASA  Mazandaran      18332    Tonekabon
#
#        Station_Latitude  Station_Longitude  Station_Elevation  \
# 0                 36.07              52.84             1805.0
# 1                 36.07              52.84             1805.0
# 2                 36.07              52.84             1805.0
# 3                 36.07              52.84             1805.0
# 4                 36.07              52.84             1805.0
# ...                 ...                ...                ...
# 21523             36.81              50.90                0.0
# 21524             36.81              50.90                0.0
# 21525             36.81              50.90                0.0
# 21526             36.81              50.90                0.0
# 21527             36.81              50.90                0.0
#
#        Temperature_Maximum  Temperature_Maximum_count  Temperature_Minimum  \
# 0                      NaN                          0                  NaN
# 1                      NaN                          0                  NaN
# 2                      NaN                          0                  NaN
# 3                      NaN                          0                  NaN
# 4                      NaN                          0                  NaN
# ...                    ...                        ...                  ...
# 21523                23.29                         31                16.94
# 21524                28.14                         30                20.48
# 21525                31.49                         25                25.30
# 21526                31.90                         31                24.66
# 21527                28.20                         21                21.73
#
#        Temperature_Minimum_count  Temperature  Temperature_count  \
# 0                              0          NaN                  0
# 1                              0          NaN                  0
# 2                              0          NaN                  0
# 3                              0          NaN                  0
# 4                              0          NaN                  0
# ...                          ...          ...                ...
# 21523                         31        20.11                 31
# 21524                         30        24.31                 30
# 21525                         27        28.06                 24
# 21526                         31        28.28                 31
# 21527                         21        24.96                 21
#
#        Precipitation  Precipitation_count
# 0                NaN                    0
# 1                NaN                    0
# 2                NaN                    0
# 3                NaN                    0
# 4                NaN                    0
# ...              ...                  ...
# 21523           22.4                   31
# 21524           20.8                   30
# 21525            2.6                   30
# 21526           48.5                   30
# 21527          133.0                   21
#
# [21528 rows x 17 columns]

# %%
PET_Hargreaves = daily_geoinfo_data.set_index(['Date'])\
    .groupby(by="Station_ID")\
    .apply(lambda x: round(pyet.hargreaves(tmean=x['Temperature'], tmax=x['Temperature_Maximum'], tmin=x['Temperature_Minimum'], lat=pyet.utils.deg_to_rad(x['Station_Latitude'].iloc[0])), 2), include_groups=False)\
    .stack(future_stack=True).reset_index()\
    .rename(columns={0: 'PET_Hargreaves'})

daily_geoinfo_data = daily_geoinfo_data.merge(PET_Hargreaves, on=['Date', 'Station_ID'], how='left')
daily_geoinfo_data
# Out:
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/pooya/w/DroughtMonitoringIran/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#        Station_ID       Date  Temperature_Maximum  Temperature_Minimum  \
# 0           40759 2006-09-01                 38.4                 24.8
# 1           40759 2006-09-02                 36.6                 23.0
# 2           40759 2006-09-03                 35.8                 23.8
# 3           40759 2006-09-04                 34.4                 22.6
# 4           40759 2006-09-05                 33.8                 24.4
# ...           ...        ...                  ...                  ...
# 156283      40719 2024-06-25                 31.4                 23.0
# 156284      40719 2024-06-26                 30.6                 24.0
# 156285      40719 2024-06-27                 24.0                 18.8
# 156286      40719 2024-06-28                 24.8                 19.4
# 156287      40719 2024-06-29                 26.0                 21.2
#
#         Temperature  Precipitation Station_Name    Province  Station_Latitude  \
# 0              31.6            0.0         Sari  Mazandaran            36.536
# 1              29.8            0.0         Sari  Mazandaran            36.536
# 2              29.8            0.0         Sari  Mazandaran            36.536
# 3              28.5            0.0         Sari  Mazandaran            36.536
# 4              29.1            0.0         Sari  Mazandaran            36.536
# ...             ...            ...          ...         ...               ...
# 156283         27.2            0.0        Rasht       Gilan            37.323
# 156284         27.3            0.0        Rasht       Gilan            37.323
# 156285         21.4           51.0        Rasht       Gilan            37.323
# 156286         22.1            5.2        Rasht       Gilan            37.323
# 156287         23.6            0.0        Rasht       Gilan            37.323
#
#         Station_Longitude  Station_Elevation  PET_Hargreaves
# 0                  52.998               23.0            5.90
# 1                  52.998               23.0            5.64
# 2                  52.998               23.0            5.27
# 3                  52.998               23.0            5.05
# 4                  52.998               23.0            4.54
# ...                   ...                ...             ...
# 156283             49.624               -8.6            5.13
# 156284             49.624               -8.6            4.56
# 156285             49.624               -8.6            3.50
# 156286             49.624               -8.6            3.63
# 156287             49.624               -8.6            3.55
#
# [156288 rows x 12 columns]

# %%
min_count = 25

pet_monthly = (
    daily_geoinfo_data[['Station_ID', 'Date', 'PET_Hargreaves']]\
    .set_index('Date')
    .groupby(by='Station_ID')
    .resample(rule='ME')
    .agg(
        {
            'PET_Hargreaves': lambda x: x.sum(min_count=min_count),
        }
    )
).reset_index()

pet_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5136 entries, 0 to 5135
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Station_ID      5136 non-null   object
#  1   Date            5136 non-null   datetime64[ns]
#  2   PET_Hargreaves  5104 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 120.5+ KB

# %%
df = pet_monthly.copy()
df['Month'] = df['Date'].dt.month
monthly_avg = df.groupby(['Station_ID', 'Month'])[['PET_Hargreaves']].mean(numeric_only=True)

def replace_with_avg(row):
    if pd.isna(row['PET_Hargreaves']):
        return monthly_avg.loc[(row['Station_ID'], row['Month']), 'PET_Hargreaves']
    else:
        return row['PET_Hargreaves']

df['PET_Hargreaves'] = df.apply(lambda row: replace_with_avg(row), axis=1)

df.drop(columns=['Month'], inplace=True)

pet_monthly = df.copy()

pet_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5136 entries, 0 to 5135
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Station_ID      5136 non-null   object
#  1   Date            5136 non-null   datetime64[ns]
#  2   PET_Hargreaves  5136 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 120.5+ KB

# %%
conn = sqlite3.connect(DATABASE_PATH)

daily_geoinfo_data[['Station_ID', 'Date', 'PET_Hargreaves']].to_sql('ground_pet_daily', conn, if_exists='replace', index=False)
pet_monthly.to_sql('ground_pet_monthly', conn, if_exists='replace', index=False)

conn.commit()
conn.close()
